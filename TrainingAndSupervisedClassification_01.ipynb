# %%
'''
Random hint: if you want to add a package to a virtual environment, try the following:
USING CONDA


USING PIP
source activate ee 
pip install pygeoj #here, pip points to the pip in the ee virtual environment
'''

import ee
from IPython.display import Image

# Trigger the authentication flow.
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=QFb3-Q_xtYwl41qDkqzpYfxKPIOkupIHKuxfFX7XbIw&code_challenge_method=S256>https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=QFb3-Q_xtYwl41qDkqzpYfxKPIOkupIHKuxfFX7XbIw&code_challenge_method=S256</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code: 4/0wFidobGOgFs5bGyP81qkB9m6OIiS_EGVlQkAejo3X2DpCivE6-MzXU
#
# Successfully saved authorization token.

# %%
ee.Initialize()

def get_images(path_list, row_list, satellite, start_date, end_date, max_cloud_percentage):
  coll = ee.ImageCollection(satellite).filterDate(start_date, end_date)\
            .filter(ee.Filter.inList('WRS_PATH', path_list))\
            .filter(ee.Filter.inList('WRS_ROW', row_list))\
            .filter(ee.Filter.lt('CLOUD_COVER', max_cloud_percentage))
  image_ids = list(map(lambda x: x['id'], coll.getInfo()['features']))

  images = list(map(lambda x: ee.Image(x), image_ids))

  return images

# %%
p = [14]
r = [32]
sat = 'LANDSAT/LC08/C01/T1'
sd = '2013-05-01'
ed = '2020-05-01'
cc= 10

image_list_nyc = get_images(p, r, sat, sd, ed, cc)

# %%
# !pwd
# Out:
# /Users/connorfinn/repos/earth_analytics

# %%
'''
Functions needed to display images and features/featurecollections are given here. 
These functions are all from other sources. Mostly from google tutorials.
'''
import geojson
import json
import pygeoj
import numpy as np


import folium


# Define a method for displaying Earth Engine image tiles to folium map.
def add_ee_layer(self, ee_image_object, vis_params, name):
  map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
  folium.raster_layers.TileLayer(
    tiles = map_id_dict['tile_fetcher'].url_format,
    attr = "Map Data © Google Earth Engine",
    name = name,
    overlay = True,
    control = True
  ).add_to(self)

# Add EE drawing method to folium.
folium.Map.add_ee_layer = add_ee_layer

#@title Mapdisplay: Display GEE objects using folium.
def Mapdisplay(center, dicc, Tiles="OpensTreetMap",zoom_start=10):
    '''
    :param center: Center of the map (Latitude and Longitude).
    :param dicc: Earth Engine Geometries or Tiles dictionary
    :param Tiles: Mapbox Bright,Mapbox Control Room,Stamen Terrain,Stamen Toner,stamenwatercolor,cartodbpositron.
    :zoom_start: Initial zoom level for the map.
    :return: A folium.Map object.
    '''
    mapViz = folium.Map(location=center,tiles=Tiles, zoom_start=zoom_start)
    for k,v in dicc.items():
      if ee.image.Image in [type(x) for x in v.values()]:
        folium.TileLayer(
            tiles = v["tile_fetcher"].url_format,
            attr  = 'Google Earth Engine',
            overlay =True,
            name  = k
          ).add_to(mapViz)
      else:
        folium.GeoJson(
        data = v,
        name = k
          ).add_to(mapViz)
    mapViz.add_child(folium.LayerControl())
    return mapViz

# %%
'''
In this cell, I show how you can take GeoJSON files and convert them into Google Earth Engine features and 
featurecollections. You might have created the GeoJSON files by some other means - one of them is
to use Google Earth to draw a polygon, save it as a kml file, and use ogr2ogr to conert  it to a GeoJSON file. I
created 4 such files, titled 'Hudson01.json', 'Hudson02.json', 'Bronx01.json', and 'Astoria01.json'. 

For those from NYC, or if you have a knowledge of the geography of NYC, you'd have guess  that 'Hudson01.json', and
'Hudson02.json' are regions in water, and that 'Bronx01.json', and 'Astoria01.json' correspond to land (not water).
Hence, I have created two lists jsonfiles and classalloc. landcover = 1 corresponds to water, and landcover = 0 to 
'not water'. 
'''

jsonfiles = ['Hudson01', 'Hudson02', 'Bronx01', 'Astoria01'];
classalloc = [1, 1, 0, 0];

'''
These dictionaries are to store intermediate objects before we get to features and feature collections. First,
we extract the data from the GeoJSON file. Then we extract the coordinates as a list. The list is converted into
a earth engine polygon. Finally, the polygon is converted into a feature. The feature has two attributes - 'name'
and 'class'. Both are taken from corresponding values of jsonfiles and classalloc.

Addendum: I realized, maybe wrongly, that the training data for supervized classification has to be given in the
form of points - discrete points (vector data), with each point having a property called 'landcover'. This 
landcover can take on values of 0 or 1. Hence, we need to convert the polygons we created (Hudson01.json, etc) 
into a collection of points. Whay I have done is to take the polygonal regions and determine approximately 1000
random points within the region as follows: 

ee.FeatureCollection.randomPoints(region=ee_dict[jsonfile + 'ee'],points=1000)

The above function picks random points within the area given by the keyword region. Now, this function creates a 
featurecollection of random points within a polygonal region but does not assign a property called landcover. That
is done by the next few lines. 

def addProp(feature):
    return feature.set({'landcover': classalloc[n]})

randomPoints = randomPoints.map(addProp) #This is to add a property named

The function addProp takes and feature and adds a property called landcover, the value of which is from a value
outside the scope of the function. Not sure if this is good practice, but it works. The next line with map 
automatically applies it to every feature in a feature collection. No need for messy for loops.

We need to merge all these featurecollections into one final featurecollection that can be used for training.
That is what is achieved by the lines:

fc = ee.FeatureCollection([])
for x in randomPts_dict.keys():
    print(x)
    fc = fc.merge(randomPts_dict[x])

    
'''
coords_dict = {}
ee_dict = {}
randomPts_dict = {}
features_dict = {}

n = 0
for jsonfile in jsonfiles:
    jsonfilepath =  jsonfile +'.json'
    with open(jsonfilepath) as f:
        data = geojson.load(f)
    
    #creating a dictionary of coordinates
    coords_dict[jsonfile + 'coords'] = np.array(data['features'][0]['geometry']['coordinates'][0])[:,0:2].tolist()
    
    #creating a polygon from coordinate list
    ee_dict[jsonfile + 'ee'] = ee.Geometry.Polygon(coords_dict[jsonfile + 'coords'])
    
    
    #randomPoints = ee.FeatureCollection.randomPoints(region=ee_dict[jsonfile + 'ee'],points=100, {'name': jsonfile, 'landcover': classalloc[n]})
    randomPoints = ee.FeatureCollection.randomPoints(region=ee_dict[jsonfile + 'ee'],points=30)
    
    def addProp(feature):
      return feature.set({'landcover': classalloc[n]})

    randomPoints = randomPoints.map(addProp) #This is to add a property named
    
    #randomPts_dict[jsonfile+'Pts'] = ee.Feature(ee.Geometry.MultiPoint(ee.List(coords_dict[jsonfile + 'coords'])), 
    #                                            {'name': jsonfile, 'class': classalloc[n]})
    
    randomPts_dict[jsonfile+'Pts'] = randomPoints
    
    
    
    #randomPts_dict[jsonfile + 'rdnmPts'] = ee.FeatureCollection.randomPoints(ee_dict[jsonfile + 'ee'], 100)
    features_dict[jsonfile + 'feature'] = ee.Feature(ee_dict[jsonfile + 'ee'], {'name': jsonfile, 'landcover': classalloc[n]})

    n = n+1

    
'''
The individual features are combined as shown below to create a feature collection.

You can get some information about the features in the collection using commands as shown below.
'''
nycFC = ee.FeatureCollection(list(features_dict.values()))

nycFCpts = ee.FeatureCollection(list(randomPts_dict.values()))

fc = ee.FeatureCollection([])
for x in randomPts_dict.keys():
    #print(x) #I had used this to make sure the loop was okay
    fc = fc.merge(randomPts_dict[x])


print(nycFC.size().getInfo())

print(type(nycFC.getInfo()))

print(nycFC.getInfo()['features'][3]['properties'])


'''
Displaying a featurecollection
'''
nycFC_centroid = nycFC.geometry().centroid().getInfo()['coordinates']
nycFC_centroid.reverse()
#Mapdisplay(nycFC_centroid,{'nycFC':nycFC.getInfo()},zoom_start=10)
Mapdisplay(nycFC_centroid, {'rndmPts': fc.getInfo()}, zoom_start=10)
# Out:
# 4
# <class 'dict'>
# {'landcover': 0, 'name': 'Astoria01'}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Various commands to interrogate the nature of nycFC or any featurecollection
#print(nycFC.getInfo()['features'][3]) 
print(nycFC.getInfo()['type'])
# Out:
# FeatureCollection

# %%
#To determine number of eatures in a featurecollection
nycFC.size().getInfo()
# Out:
# 4

# %%
print(nycFC.geometry().getInfo()['type']) #multpolygon
print(fc.geometry().getInfo()['type']) #Multipoint

fc.geometry().geometries().getInfo()
#Try nycFC.geometry().geometries().getInfo() to see the difference between nycFC and fc
# Out:
# MultiPolygon
# MultiPoint
# [{'type': 'Point', 'coordinates': [-73.97726913448903, 40.80338152219788]},
#  {'type': 'Point', 'coordinates': [-73.96308775134366, 40.82843265930131]},
#  {'type': 'Point', 'coordinates': [-73.95761005004844, 40.84776534504073]},
#  {'type': 'Point', 'coordinates': [-73.98212436310615, 40.79733458724368]},
#  {'type': 'Point', 'coordinates': [-73.95515245391664, 40.835706162212276]},
#  {'type': 'Point', 'coordinates': [-73.98454721702588, 40.796822194775984]},
#  {'type': 'Point', 'coordinates': [-73.98541469961975, 40.79179870176999]},
#  {'type': 'Point', 'coordinates': [-73.9617751516699, 40.83534902988346]},
#  {'type': 'Point', 'coordinates': [-73.9864166821032, 40.79159075870921]},
#  {'type': 'Point', 'coordinates': [-73.98286424708584, 40.79560622044268]},
#  {'type': 'Point', 'coordinates': [-73.97524317791985, 40.81207140261596]},
#  {'type': 'Point', 'coordinates': [-73.9528559673429, 40.84238548075046]},
#  {'type': 'Point', 'coordinates': [-73.97355454085583, 40.817686633532716]},
#  {'type': 'Point', 'coordinates': [-73.97034603756892, 40.82052859100451]},
#  {'type': 'Point', 'coordinates': [-73.96551066224514, 40.82033811461513]},
#  {'type': 'Point', 'coordinates': [-73.98610292616212, 40.79466395608381]},
#  {'type': 'Point', 'coordinates': [-73.96796555519884, 40.820242042438025]},
#  {'type': 'Point', 'coordinates': [-73.9699518786234, 40.81402250288002]},
#  {'type': 'Point', 'coordinates': [-73.95821733959389, 40.84385665958896]},
#  {'type': 'Point', 'coordinates': [-73.98170597599717, 40.80347573801371]},
#  {'type': 'Point', 'coordinates': [-73.9753984974232, 40.81164887877697]},
#  {'type': 'Point', 'coordinates': [-73.9884106693513, 40.79096231154915]},
#  {'type': 'Point', 'coordinates': [-73.9779984996434, 40.80884878541013]},
#  {'type': 'Point', 'coordinates': [-73.98182296875586, 40.79671628768962]},
#  {'type': 'Point', 'coordinates': [-73.97447508756919, 40.81650932041327]},
#  {'type': 'Point', 'coordinates': [-73.97075696141155, 40.81945222901834]},
#  {'type': 'Point', 'coordinates': [-73.96556015685822, 40.821234862316935]},
#  {'type': 'Point', 'coordinates': [-73.98254379037982, 40.79466365669443]},
#  {'type': 'Point', 'coordinates': [-73.96164476489672, 40.826396877826106]},
#  {'type': 'Point', 'coordinates': [-73.98507029063272, 40.79048848623656]},
#  {'type': 'Point', 'coordinates': [-73.93552247679578, 40.872233618646526]},
#  {'type': 'Point', 'coordinates': [-73.94363938214886, 40.86232822342618]},
#  {'type': 'Point', 'coordinates': [-73.94798588359137, 40.85448597612985]},
#  {'type': 'Point', 'coordinates': [-73.93621587788225, 40.88706891403025]},
#  {'type': 'Point', 'coordinates': [-73.93513369957786, 40.86925833863237]},
#  {'type': 'Point', 'coordinates': [-73.93616556543076, 40.88248108674617]},
#  {'type': 'Point', 'coordinates': [-73.94737021279262, 40.85762300436165]},
#  {'type': 'Point', 'coordinates': [-73.94052014773933, 40.865980248815795]},
#  {'type': 'Point', 'coordinates': [-73.93690994051892, 40.87540514366874]},
#  {'type': 'Point', 'coordinates': [-73.93636686735287, 40.87903534225505]},
#  {'type': 'Point', 'coordinates': [-73.93799260587662, 40.87834760946709]},
#  {'type': 'Point', 'coordinates': [-73.93199525356428, 40.873667934061274]},
#  {'type': 'Point', 'coordinates': [-73.94793658823266, 40.866527467134624]},
#  {'type': 'Point', 'coordinates': [-73.93559991310752, 40.878852693263504]},
#  {'type': 'Point', 'coordinates': [-73.94611998572537, 40.86127466031828]},
#  {'type': 'Point', 'coordinates': [-73.943879992182, 40.87012324578912]},
#  {'type': 'Point', 'coordinates': [-73.93757327543996, 40.87188413275667]},
#  {'type': 'Point', 'coordinates': [-73.93695160397134, 40.868740785500336]},
#  {'type': 'Point', 'coordinates': [-73.94789151199042, 40.85650234006507]},
#  {'type': 'Point', 'coordinates': [-73.94062064606223, 40.875712445091985]},
#  {'type': 'Point', 'coordinates': [-73.9390663455032, 40.880699686754745]},
#  {'type': 'Point', 'coordinates': [-73.93966416119329, 40.87235691277902]},
#  {'type': 'Point', 'coordinates': [-73.94024007122668, 40.87527942702987]},
#  {'type': 'Point', 'coordinates': [-73.93607871150797, 40.88865016675204]},
#  {'type': 'Point', 'coordinates': [-73.94903305268106, 40.86481051253456]},
#  {'type': 'Point', 'coordinates': [-73.93633856351026, 40.87908396973311]},
#  {'type': 'Point', 'coordinates': [-73.94542604187335, 40.862545504770665]},
#  {'type': 'Point', 'coordinates': [-73.9378908492582, 40.867671000420856]},
#  {'type': 'Point', 'coordinates': [-73.92672428890369, 40.89153310370346]},
#  {'type': 'Point', 'coordinates': [-73.92561540653048, 40.89030577059908]},
#  {'type': 'Point', 'coordinates': [-73.89658322122182, 40.81844704596529]},
#  {'type': 'Point', 'coordinates': [-73.90793933878902, 40.81969568994555]},
#  {'type': 'Point', 'coordinates': [-73.92207536092175, 40.80999035993362]},
#  {'type': 'Point', 'coordinates': [-73.90998217578269, 40.81085138942566]},
#  {'type': 'Point', 'coordinates': [-73.89012732238736, 40.82310823395308]},
#  {'type': 'Point', 'coordinates': [-73.88678205477684, 40.81538717019095]},
#  {'type': 'Point', 'coordinates': [-73.90608000260443, 40.80734081452122]},
#  {'type': 'Point', 'coordinates': [-73.91242234305072, 40.81345206698678]},
#  {'type': 'Point', 'coordinates': [-73.91447385310862, 40.81534276521771]},
#  {'type': 'Point', 'coordinates': [-73.91209369828665, 40.810669836187955]},
#  {'type': 'Point', 'coordinates': [-73.88252174132609, 40.81499685253721]},
#  {'type': 'Point', 'coordinates': [-73.893048064655, 40.82547661569048]},
#  {'type': 'Point', 'coordinates': [-73.9179813491263, 40.80492801241158]},
#  {'type': 'Point', 'coordinates': [-73.89626766794807, 40.80966507036804]},
#  {'type': 'Point', 'coordinates': [-73.90056945111967, 40.823562308423476]},
#  {'type': 'Point', 'coordinates': [-73.89076840780444, 40.816136082433985]},
#  {'type': 'Point', 'coordinates': [-73.9101673327282, 40.8213062659063]},
#  {'type': 'Point', 'coordinates': [-73.91025711020956, 40.82754202611094]},
#  {'type': 'Point', 'coordinates': [-73.88018619474161, 40.81332118650753]},
#  {'type': 'Point', 'coordinates': [-73.8870691840875, 40.81199874406277]},
#  {'type': 'Point', 'coordinates': [-73.89156015972769, 40.811408189192775]},
#  {'type': 'Point', 'coordinates': [-73.9036796213514, 40.81886750993873]},
#  {'type': 'Point', 'coordinates': [-73.88954128359332, 40.81363751546122]},
#  {'type': 'Point', 'coordinates': [-73.89205095902274, 40.81068600837269]},
#  {'type': 'Point', 'coordinates': [-73.9207434665599, 40.806429815518534]},
#  {'type': 'Point', 'coordinates': [-73.88109696957096, 40.81462774296114]},
#  {'type': 'Point', 'coordinates': [-73.90062552415719, 40.82190111918505]},
#  {'type': 'Point', 'coordinates': [-73.91898338878856, 40.80914916779409]},
#  {'type': 'Point', 'coordinates': [-73.91087490792764, 40.82859942438753]},
#  {'type': 'Point', 'coordinates': [-73.9189827488195, 40.804123612835454]},
#  {'type': 'Point', 'coordinates': [-73.92203629357051, 40.763676621925164]},
#  {'type': 'Point', 'coordinates': [-73.91871237083838, 40.76422849735108]},
#  {'type': 'Point', 'coordinates': [-73.92881354132867, 40.76479098474038]},
#  {'type': 'Point', 'coordinates': [-73.92132891671262, 40.765923751402326]},
#  {'type': 'Point', 'coordinates': [-73.93023172339797, 40.76672229998491]},
#  {'type': 'Point', 'coordinates': [-73.92427437208441, 40.76400309696836]},
#  {'type': 'Point', 'coordinates': [-73.91749214913304, 40.76251164401785]},
#  {'type': 'Point', 'coordinates': [-73.91757137161306, 40.762259444594115]},
#  {'type': 'Point', 'coordinates': [-73.92589614540735, 40.76595893833707]},
#  {'type': 'Point', 'coordinates': [-73.9206436520613, 40.7661418915763]},
#  {'type': 'Point', 'coordinates': [-73.9263560939088, 40.764577921904696]},
#  {'type': 'Point', 'coordinates': [-73.91658602378945, 40.76625191668435]},
#  {'type': 'Point', 'coordinates': [-73.91715590645533, 40.76683393415903]},
#  {'type': 'Point', 'coordinates': [-73.9280798169411, 40.76488190305168]},
#  {'type': 'Point', 'coordinates': [-73.91939868959375, 40.76301930976759]},
#  {'type': 'Point', 'coordinates': [-73.91929357605814, 40.767526024838816]},
#  {'type': 'Point', 'coordinates': [-73.92410845571196, 40.7670701260946]},
#  {'type': 'Point', 'coordinates': [-73.92330899999226, 40.76808235624977]},
#  {'type': 'Point', 'coordinates': [-73.92823900913149, 40.765432756821625]},
#  {'type': 'Point', 'coordinates': [-73.92255672843007, 40.76609871918763]},
#  {'type': 'Point', 'coordinates': [-73.92615193718883, 40.76465436186263]},
#  {'type': 'Point', 'coordinates': [-73.9229180500496, 40.76688455602875]},
#  {'type': 'Point', 'coordinates': [-73.92366280546864, 40.76594347530442]},
#  {'type': 'Point', 'coordinates': [-73.92027486666326, 40.76651180417262]},
#  {'type': 'Point', 'coordinates': [-73.9182722380914, 40.7672729786607]},
#  {'type': 'Point', 'coordinates': [-73.92739052890501, 40.76483923939484]},
#  {'type': 'Point', 'coordinates': [-73.91990664530465, 40.76332544615624]},
#  {'type': 'Point', 'coordinates': [-73.92228169693055, 40.76840764705168]},
#  {'type': 'Point', 'coordinates': [-73.92402695122342, 40.76824389645122]},
#  {'type': 'Point', 'coordinates': [-73.91456806585691, 40.76575305543385]}]

# %%
# What properties do the constituent features of the featureCollection have?
#nycFC.getInfo()['features'][0]['properties']
fc.getInfo()
# Out:
# {'type': 'FeatureCollection',
#  'columns': {},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97726913448903, 40.80338152219788]},
#    'id': '1_1_1_2_0',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96308775134366, 40.82843265930131]},
#    'id': '1_1_1_2_1',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.95761005004844, 40.84776534504073]},
#    'id': '1_1_1_2_2',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98212436310615, 40.79733458724368]},
#    'id': '1_1_1_2_3',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.95515245391664, 40.835706162212276]},
#    'id': '1_1_1_2_4',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98454721702588, 40.796822194775984]},
#    'id': '1_1_1_2_5',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98541469961975, 40.79179870176999]},
#    'id': '1_1_1_2_6',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9617751516699, 40.83534902988346]},
#    'id': '1_1_1_2_7',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9864166821032, 40.79159075870921]},
#    'id': '1_1_1_2_8',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98286424708584, 40.79560622044268]},
#    'id': '1_1_1_2_9',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97524317791985, 40.81207140261596]},
#    'id': '1_1_1_2_10',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9528559673429, 40.84238548075046]},
#    'id': '1_1_1_2_11',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97355454085583, 40.817686633532716]},
#    'id': '1_1_1_2_12',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97034603756892, 40.82052859100451]},
#    'id': '1_1_1_2_13',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96551066224514, 40.82033811461513]},
#    'id': '1_1_1_2_14',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98610292616212, 40.79466395608381]},
#    'id': '1_1_1_2_15',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96796555519884, 40.820242042438025]},
#    'id': '1_1_1_2_16',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9699518786234, 40.81402250288002]},
#    'id': '1_1_1_2_17',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.95821733959389, 40.84385665958896]},
#    'id': '1_1_1_2_18',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98170597599717, 40.80347573801371]},
#    'id': '1_1_1_2_19',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9753984974232, 40.81164887877697]},
#    'id': '1_1_1_2_20',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9884106693513, 40.79096231154915]},
#    'id': '1_1_1_2_21',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9779984996434, 40.80884878541013]},
#    'id': '1_1_1_2_22',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98182296875586, 40.79671628768962]},
#    'id': '1_1_1_2_23',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97447508756919, 40.81650932041327]},
#    'id': '1_1_1_2_24',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97075696141155, 40.81945222901834]},
#    'id': '1_1_1_2_25',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96556015685822, 40.821234862316935]},
#    'id': '1_1_1_2_26',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98254379037982, 40.79466365669443]},
#    'id': '1_1_1_2_27',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96164476489672, 40.826396877826106]},
#    'id': '1_1_1_2_28',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98507029063272, 40.79048848623656]},
#    'id': '1_1_1_2_29',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93552247679578, 40.872233618646526]},
#    'id': '1_1_2_0',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94363938214886, 40.86232822342618]},
#    'id': '1_1_2_1',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94798588359137, 40.85448597612985]},
#    'id': '1_1_2_2',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93621587788225, 40.88706891403025]},
#    'id': '1_1_2_3',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93513369957786, 40.86925833863237]},
#    'id': '1_1_2_4',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93616556543076, 40.88248108674617]},
#    'id': '1_1_2_5',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94737021279262, 40.85762300436165]},
#    'id': '1_1_2_6',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94052014773933, 40.865980248815795]},
#    'id': '1_1_2_7',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93690994051892, 40.87540514366874]},
#    'id': '1_1_2_8',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93636686735287, 40.87903534225505]},
#    'id': '1_1_2_9',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93799260587662, 40.87834760946709]},
#    'id': '1_1_2_10',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93199525356428, 40.873667934061274]},
#    'id': '1_1_2_11',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94793658823266, 40.866527467134624]},
#    'id': '1_1_2_12',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93559991310752, 40.878852693263504]},
#    'id': '1_1_2_13',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94611998572537, 40.86127466031828]},
#    'id': '1_1_2_14',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.943879992182, 40.87012324578912]},
#    'id': '1_1_2_15',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93757327543996, 40.87188413275667]},
#    'id': '1_1_2_16',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93695160397134, 40.868740785500336]},
#    'id': '1_1_2_17',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94789151199042, 40.85650234006507]},
#    'id': '1_1_2_18',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94062064606223, 40.875712445091985]},
#    'id': '1_1_2_19',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9390663455032, 40.880699686754745]},
#    'id': '1_1_2_20',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93966416119329, 40.87235691277902]},
#    'id': '1_1_2_21',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94024007122668, 40.87527942702987]},
#    'id': '1_1_2_22',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93607871150797, 40.88865016675204]},
#    'id': '1_1_2_23',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94903305268106, 40.86481051253456]},
#    'id': '1_1_2_24',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93633856351026, 40.87908396973311]},
#    'id': '1_1_2_25',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94542604187335, 40.862545504770665]},
#    'id': '1_1_2_26',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9378908492582, 40.867671000420856]},
#    'id': '1_1_2_27',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92672428890369, 40.89153310370346]},
#    'id': '1_1_2_28',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92561540653048, 40.89030577059908]},
#    'id': '1_1_2_29',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89658322122182, 40.81844704596529]},
#    'id': '1_2_0',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.90793933878902, 40.81969568994555]},
#    'id': '1_2_1',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92207536092175, 40.80999035993362]},
#    'id': '1_2_2',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.90998217578269, 40.81085138942566]},
#    'id': '1_2_3',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89012732238736, 40.82310823395308]},
#    'id': '1_2_4',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.88678205477684, 40.81538717019095]},
#    'id': '1_2_5',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.90608000260443, 40.80734081452122]},
#    'id': '1_2_6',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91242234305072, 40.81345206698678]},
#    'id': '1_2_7',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91447385310862, 40.81534276521771]},
#    'id': '1_2_8',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91209369828665, 40.810669836187955]},
#    'id': '1_2_9',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.88252174132609, 40.81499685253721]},
#    'id': '1_2_10',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.893048064655, 40.82547661569048]},
#    'id': '1_2_11',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9179813491263, 40.80492801241158]},
#    'id': '1_2_12',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89626766794807, 40.80966507036804]},
#    'id': '1_2_13',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.90056945111967, 40.823562308423476]},
#    'id': '1_2_14',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89076840780444, 40.816136082433985]},
#    'id': '1_2_15',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9101673327282, 40.8213062659063]},
#    'id': '1_2_16',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91025711020956, 40.82754202611094]},
#    'id': '1_2_17',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.88018619474161, 40.81332118650753]},
#    'id': '1_2_18',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.8870691840875, 40.81199874406277]},
#    'id': '1_2_19',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89156015972769, 40.811408189192775]},
#    'id': '1_2_20',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9036796213514, 40.81886750993873]},
#    'id': '1_2_21',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.88954128359332, 40.81363751546122]},
#    'id': '1_2_22',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89205095902274, 40.81068600837269]},
#    'id': '1_2_23',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9207434665599, 40.806429815518534]},
#    'id': '1_2_24',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.88109696957096, 40.81462774296114]},
#    'id': '1_2_25',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.90062552415719, 40.82190111918505]},
#    'id': '1_2_26',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91898338878856, 40.80914916779409]},
#    'id': '1_2_27',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91087490792764, 40.82859942438753]},
#    'id': '1_2_28',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9189827488195, 40.804123612835454]},
#    'id': '1_2_29',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92203629357051, 40.763676621925164]},
#    'id': '2_0',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91871237083838, 40.76422849735108]},
#    'id': '2_1',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92881354132867, 40.76479098474038]},
#    'id': '2_2',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92132891671262, 40.765923751402326]},
#    'id': '2_3',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93023172339797, 40.76672229998491]},
#    'id': '2_4',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92427437208441, 40.76400309696836]},
#    'id': '2_5',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91749214913304, 40.76251164401785]},
#    'id': '2_6',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91757137161306, 40.762259444594115]},
#    'id': '2_7',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92589614540735, 40.76595893833707]},
#    'id': '2_8',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9206436520613, 40.7661418915763]},
#    'id': '2_9',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9263560939088, 40.764577921904696]},
#    'id': '2_10',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91658602378945, 40.76625191668435]},
#    'id': '2_11',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91715590645533, 40.76683393415903]},
#    'id': '2_12',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9280798169411, 40.76488190305168]},
#    'id': '2_13',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91939868959375, 40.76301930976759]},
#    'id': '2_14',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91929357605814, 40.767526024838816]},
#    'id': '2_15',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92410845571196, 40.7670701260946]},
#    'id': '2_16',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92330899999226, 40.76808235624977]},
#    'id': '2_17',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92823900913149, 40.765432756821625]},
#    'id': '2_18',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92255672843007, 40.76609871918763]},
#    'id': '2_19',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92615193718883, 40.76465436186263]},
#    'id': '2_20',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9229180500496, 40.76688455602875]},
#    'id': '2_21',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92366280546864, 40.76594347530442]},
#    'id': '2_22',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92027486666326, 40.76651180417262]},
#    'id': '2_23',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9182722380914, 40.7672729786607]},
#    'id': '2_24',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92739052890501, 40.76483923939484]},
#    'id': '2_25',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91990664530465, 40.76332544615624]},
#    'id': '2_26',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92228169693055, 40.76840764705168]},
#    'id': '2_27',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92402695122342, 40.76824389645122]},
#    'id': '2_28',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91456806585691, 40.76575305543385]},
#    'id': '2_29',
#    'properties': {'landcover': 0}}]}

# %%
#How to join features into a featurecollection
'''
This is code I took from 
https://colab.research.google.com/github/csaybar/EEwPython/blob/master/4_features.ipynb#scrollTo=G-JXF_byXB01
to understand how to combine features into featurecollections.
'''
features_list_example = [
  ee.Feature(ee.Geometry.Rectangle(30.01, 59.80, 30.59, 60.15), {'name': 'Voronoi'}),
  ee.Feature(ee.Geometry.Point(-73.96, 40.781), {'name': 'Thiessen'}),
  ee.Feature(ee.Geometry.Point(6.4806, 50.8012), {'name': 'Dirichlet'})
];

fromList = ee.FeatureCollection(features_list_example) 

print(fromList.size().getInfo())
# Out:
# 3

# %%
nycsite = ee.Geometry.Rectangle([-74.04, 40.69, -73.82, 40.94]);

image0 = image_list_nyc[0] #one image from the list of images

parameters = {'min': 0.0,
              'max': 16000.0,
              'dimensions': 768,
              'bands': ['B4', 'B3', 'B2']}

Image(url = image0.clip(nycsite).getThumbUrl(parameters))
# Out:
# <img src="https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d5c5b7a38ba07fa401480418b044b6d2-8dda501869e3ace2d0ab623f207c6f03:getPixels"/>

# %%
'''
Second step in any supervised classification process - training using the training data. The corresponding
code in Google EE tutorial is as follows:
// Get the values for all pixels in each polygon in the training.
var training = image.sampleRegions({
  // Get the sample from the polygons FeatureCollection.
  collection: polygons,
  // Keep this list of properties from the polygons.
  properties: ['class'],
  // Set the scale to get Landsat pixels in the polygons.
  scale: 30
});

The code is in javascript. I had to convert it to Python. Mistakes could be created/transmitted because of this
translation
'''
bands = ['B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B10', 'B11']
#bands = ['B2', 'B3', 'B4', 'B5', 'B6', 'B7']

training = image0.select(bands).sampleRegions(collection =  fc, properties = ['landcover'], scale = 30.0)
#print(training.geometry().getInfo()['type'])

'''
We can view feature collections using Mapdisplay, the function we encountered earlier. THe way to do it is as follows:
Mapdisplay(center,dicc={'poly1':hudson02ee.getInfo(),'poly2':hudson01ee.getInfo(), 'poly3': Astoria01ee.getInfo(), 'poly4': Bronx01ee.getInfo()},zoom_start=2)
'''

training_centroid = training.geometry().centroid().getInfo()['coordinates']
training_centroid.reverse()

'''
training_centroid is also a featurecollection but different from nycFC. Try print(training.size().getInfo()) - 
you'll see that the size is about 20000, not 4. Since I cannot display training, I think there must be a mistake 
right here. Need to rectify this - understand image.sampleRegions better before proceeding further.
'''
# Out:
# "\ntraining_centroid is also a featurecollection but different from nycFC. Try print(training.size().getInfo()) - \nyou'll see that the size is about 20000, not 4. Since I cannot display training, I think there must be a mistake \nright here. Need to rectify this - understand image.sampleRegions better before proceeding further.\n"

# %%
'''
defining the classifier - is that what this step is? 
The corresponding code in Google EE tutorial from which I generated this is as follows
// Create an SVM classifier with custom parameters.
var classifier = ee.Classifier.libsvm({
  kernelType: 'RBF',
  gamma: 0.5,
  cost: 10
});

'''
#classifier = ee.Classifier.libsvm(kernelType = 'RBF', gamma = 0.5, cost = 10)
'''
Turns out the choice of the classifier is important. The choice in this cell 
ee.Classifier.libsvm(kernelType = 'RBF', gamma = 0.5, cost = 10)
did not seem to work out well. The ee.Classifier.smileCart() worked wonders. Really surprised. 
Speaks volumes about how much of a blackbox there is in machine learning.
'''
# Out:
# "\nTurns out the choice of the classifier is important. The choice in this cell \nee.Classifier.libsvm(kernelType = 'RBF', gamma = 0.5, cost = 10)\ndid not seem to work out well. The ee.Classifier.smileCart() worked wonders. Really surprised. \nSpeaks volumes about how much of a blackbox there is in machine learning.\n"

# %%
#Train the classifier.
'''
// Train the classifier.
var trained = classifier.train(training, 'class', bands);
'''
#trained = classifier.train(training, 'landcover', bands);
trained = ee.Classifier.smileCart().train(training, 'landcover', bands)
print(type(trained))
# Out:
# <class 'ee.Classifier'>

# %%
#Classify the image.
'''
This is the step at which the code is failing. If I try to interrogate classified in anyway, the computation is 
never completed. For example, if I did classified.getInfo(), an asterix * would appear next to the cell, never to 
finish.
'''
classified = image0.select(bands).classify(trained);

print(type(classified))
# Out:
# <class 'ee.image.Image'>

# %%
type(classified)
# Out:
# ee.image.Image

# %%
# Create a folium map object.
my_map = folium.Map(location=[ 40.8, -73.8], zoom_start=9, height=500)
#location should be given as latitude, longitude

my_map.add_ee_layer(image0, {'bands': ['B4', 'B3', 'B2'], 'max': 16000, 'gamma': 2}, 'image')

display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_map.add_ee_layer(classified, {'min': 0, 'max': 2, 'palette': ['white', 'blue']}, 'water')
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from IPython.display import Image
parameters = {'min': 0.0,
              'max': 1.5,
              'dimensions': 400,
              'palette': ['black', 'white'],
              #'region': ee.Geometry.Rectangle([-74.04, 40.69, -73.82, 40.94])
}
Image(url = classified.getThumbUrl(parameters))
'''
#I do see some patterns - some areas divided into black and others into white. Still, this image takes a long 
#time to display. Not sure why. 
These were comments I had when I used the not-so-effective classifier. With smileCart, it seems to work well.
'''
# Out:
# '\n#I do see some patterns - some areas divided into black and others into white. Still, this image takes a long \n#time to display. Not sure why. \nThese were comments I had when I used the not-so-effective classifier. With smileCart, it seems to work well.\n'

# %%
from ee import batch

## Make 8 bit data
def convertBit(image):
    return image.multiply(512).uint8()  

outputImage = classified.multiply(512).uint8()  

out = batch.Export.image.toDrive(image = outputImage, description = 'imageToDriveExample',  scale = 30);

process = batch.Task.start(out)

print("Process sent to cloud")
# Out:
# Process sent to cloud

# %%
buffer = hudson02ee.buffer(100).getInfo()

# Compute the centroid of the polygon.
centroid = hudson02ee.centroid().getInfo()


#Go Folium
center = centroid['coordinates']

Mapdisplay(center,{'center':centroid,'buffer':buffer},zoom_start=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-2ce5d47e3541> in <module>
# ----> 1 buffer = hudson02ee.buffer(100).getInfo()
#       2
#       3 # Compute the centroid of the polygon.
#       4 centroid = hudson02ee.centroid().getInfo()
#       5
#
# NameError: name 'hudson02ee' is not defined

# %%
Mapdisplay(center,dicc={'poly1':hudson02ee.getInfo(),'poly2':hudson01ee.getInfo(), 'poly3': Astoria01ee.getInfo(), 'poly4': Bronx01ee.getInfo()},zoom_start=2)

# %%
jsonfiles
jsonfilepath

# %%
fromList

# %%
nycFC_centroid = nycFC.geometry().centroid().getInfo()['coordinates']
fromList_centroid = fromList.geometry().centroid().getInfo()['coordinates']

# %%
fromList_centroid

# %%
nycFC.size().getInfo()

# %%
training.getInfo()

# %%
type(training)

# %%
print(training.size().getInfo())

# %%
training.style().getInfo()

# %%
training.geometry().getInfo()

# %%
nycFC.geometry().getInfo()['type']

# %%
training.geometry().getInfo()['type']

# %%
type(nycFC.geometry())

# %%
nycFCrandom = ee.FeatureCollection.randomPoints(nycFC.geometry(), 20)

# %%
type(nycFCrandom)

# %%
nycFCrandom02 = nycFCrandom.copyProperties(features_dict['Hudson01' + 'feature'], ['class'])

# %%
type(features_dict['Hudson01' + 'feature'])

# %%
def copyProps(feature, feat2copyFrom):
  return feature.copyProperties(feat2copyFrom, ['class'])

#nycFCrandom02  = nycFCrandom.map(copyProps, features_dict['Hudson01' + 'feature'])

# %%
points = ee.FeatureCollection('GOOGLE/EE/DEMOS/demo_landcover_labels')

# %%
nycFrandomPts03 = ee.Feature(ee.Geometry.MultiPoint(nycFCrandom.geometry().geometries()), {'class': 0})
print(type(nycFCrandom.geometry().geometries()))
print(type(ee.List(coords_dict[jsonfile + 'coords'] )))

# %%
nycFrandomPts03.getInfo()
#type(nycFCrandom.geometry().geometries())

# %%
nycFCpts.getInfo()

# %%
randomPoints.getInfo()

# %%
randomPoints.getInfo()

# %%
def addProp(feature):
  return feature.set({'landcover': 1})

randomPoints = randomPoints.map(addProp)

# %%
ee.Feature(ee.Geometry.MultiPoint(randomPoints.geometry().geometries()), {'landcover':0}).getInfo()

# %%
features_dict['Hudson01feature'].propertyNames().getInfo()
# Out:
# ['landcover', 'name']

# %%
randomPts_dict['Hudson02Pts'].getInfo()
# Out:
# {'type': 'FeatureCollection',
#  'columns': {'landcover': 'Integer'},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93552247679578, 40.872233618646526]},
#    'id': '0',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94363938214886, 40.86232822342618]},
#    'id': '1',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94798588359137, 40.85448597612985]},
#    'id': '2',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93621587788225, 40.88706891403025]},
#    'id': '3',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93513369957786, 40.86925833863237]},
#    'id': '4',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93616556543076, 40.88248108674617]},
#    'id': '5',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94737021279262, 40.85762300436165]},
#    'id': '6',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94052014773933, 40.865980248815795]},
#    'id': '7',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93690994051892, 40.87540514366874]},
#    'id': '8',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93636686735287, 40.87903534225505]},
#    'id': '9',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93799260587662, 40.87834760946709]},
#    'id': '10',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93199525356428, 40.873667934061274]},
#    'id': '11',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94793658823266, 40.866527467134624]},
#    'id': '12',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93559991310752, 40.878852693263504]},
#    'id': '13',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94611998572537, 40.86127466031828]},
#    'id': '14',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.943879992182, 40.87012324578912]},
#    'id': '15',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93757327543996, 40.87188413275667]},
#    'id': '16',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93695160397134, 40.868740785500336]},
#    'id': '17',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94789151199042, 40.85650234006507]},
#    'id': '18',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94062064606223, 40.875712445091985]},
#    'id': '19',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9390663455032, 40.880699686754745]},
#    'id': '20',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93966416119329, 40.87235691277902]},
#    'id': '21',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94024007122668, 40.87527942702987]},
#    'id': '22',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93607871150797, 40.88865016675204]},
#    'id': '23',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94903305268106, 40.86481051253456]},
#    'id': '24',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93633856351026, 40.87908396973311]},
#    'id': '25',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94542604187335, 40.862545504770665]},
#    'id': '26',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9378908492582, 40.867671000420856]},
#    'id': '27',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92672428890369, 40.89153310370346]},
#    'id': '28',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92561540653048, 40.89030577059908]},
#    'id': '29',
#    'properties': {'landcover': 1}}]}

# %%
xyz = randomPts_dict['Hudson01Pts'].merge(randomPts_dict['Hudson02Pts'])

# %%
xyz = xyz.merge(randomPts_dict['Astoria01Pts'])

# %%
xyz.getInfo()
# Out:
# {'type': 'FeatureCollection',
#  'columns': {'landcover': 'Integer'},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97726913448903, 40.80338152219788]},
#    'id': '1_1_0',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96308775134366, 40.82843265930131]},
#    'id': '1_1_1',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.95761005004844, 40.84776534504073]},
#    'id': '1_1_2',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98212436310615, 40.79733458724368]},
#    'id': '1_1_3',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.95515245391664, 40.835706162212276]},
#    'id': '1_1_4',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98454721702588, 40.796822194775984]},
#    'id': '1_1_5',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98541469961975, 40.79179870176999]},
#    'id': '1_1_6',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9617751516699, 40.83534902988346]},
#    'id': '1_1_7',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9864166821032, 40.79159075870921]},
#    'id': '1_1_8',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98286424708584, 40.79560622044268]},
#    'id': '1_1_9',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97524317791985, 40.81207140261596]},
#    'id': '1_1_10',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9528559673429, 40.84238548075046]},
#    'id': '1_1_11',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97355454085583, 40.817686633532716]},
#    'id': '1_1_12',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97034603756892, 40.82052859100451]},
#    'id': '1_1_13',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96551066224514, 40.82033811461513]},
#    'id': '1_1_14',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98610292616212, 40.79466395608381]},
#    'id': '1_1_15',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96796555519884, 40.820242042438025]},
#    'id': '1_1_16',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9699518786234, 40.81402250288002]},
#    'id': '1_1_17',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.95821733959389, 40.84385665958896]},
#    'id': '1_1_18',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98170597599717, 40.80347573801371]},
#    'id': '1_1_19',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9753984974232, 40.81164887877697]},
#    'id': '1_1_20',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9884106693513, 40.79096231154915]},
#    'id': '1_1_21',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9779984996434, 40.80884878541013]},
#    'id': '1_1_22',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98182296875586, 40.79671628768962]},
#    'id': '1_1_23',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97447508756919, 40.81650932041327]},
#    'id': '1_1_24',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97075696141155, 40.81945222901834]},
#    'id': '1_1_25',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96556015685822, 40.821234862316935]},
#    'id': '1_1_26',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98254379037982, 40.79466365669443]},
#    'id': '1_1_27',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96164476489672, 40.826396877826106]},
#    'id': '1_1_28',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98507029063272, 40.79048848623656]},
#    'id': '1_1_29',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93552247679578, 40.872233618646526]},
#    'id': '1_2_0',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94363938214886, 40.86232822342618]},
#    'id': '1_2_1',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94798588359137, 40.85448597612985]},
#    'id': '1_2_2',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93621587788225, 40.88706891403025]},
#    'id': '1_2_3',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93513369957786, 40.86925833863237]},
#    'id': '1_2_4',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93616556543076, 40.88248108674617]},
#    'id': '1_2_5',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94737021279262, 40.85762300436165]},
#    'id': '1_2_6',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94052014773933, 40.865980248815795]},
#    'id': '1_2_7',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93690994051892, 40.87540514366874]},
#    'id': '1_2_8',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93636686735287, 40.87903534225505]},
#    'id': '1_2_9',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93799260587662, 40.87834760946709]},
#    'id': '1_2_10',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93199525356428, 40.873667934061274]},
#    'id': '1_2_11',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94793658823266, 40.866527467134624]},
#    'id': '1_2_12',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93559991310752, 40.878852693263504]},
#    'id': '1_2_13',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94611998572537, 40.86127466031828]},
#    'id': '1_2_14',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.943879992182, 40.87012324578912]},
#    'id': '1_2_15',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93757327543996, 40.87188413275667]},
#    'id': '1_2_16',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93695160397134, 40.868740785500336]},
#    'id': '1_2_17',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94789151199042, 40.85650234006507]},
#    'id': '1_2_18',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94062064606223, 40.875712445091985]},
#    'id': '1_2_19',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9390663455032, 40.880699686754745]},
#    'id': '1_2_20',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93966416119329, 40.87235691277902]},
#    'id': '1_2_21',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94024007122668, 40.87527942702987]},
#    'id': '1_2_22',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93607871150797, 40.88865016675204]},
#    'id': '1_2_23',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94903305268106, 40.86481051253456]},
#    'id': '1_2_24',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93633856351026, 40.87908396973311]},
#    'id': '1_2_25',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94542604187335, 40.862545504770665]},
#    'id': '1_2_26',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9378908492582, 40.867671000420856]},
#    'id': '1_2_27',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92672428890369, 40.89153310370346]},
#    'id': '1_2_28',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92561540653048, 40.89030577059908]},
#    'id': '1_2_29',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92203629357051, 40.763676621925164]},
#    'id': '2_0',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91871237083838, 40.76422849735108]},
#    'id': '2_1',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92881354132867, 40.76479098474038]},
#    'id': '2_2',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92132891671262, 40.765923751402326]},
#    'id': '2_3',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93023172339797, 40.76672229998491]},
#    'id': '2_4',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92427437208441, 40.76400309696836]},
#    'id': '2_5',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91749214913304, 40.76251164401785]},
#    'id': '2_6',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91757137161306, 40.762259444594115]},
#    'id': '2_7',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92589614540735, 40.76595893833707]},
#    'id': '2_8',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9206436520613, 40.7661418915763]},
#    'id': '2_9',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9263560939088, 40.764577921904696]},
#    'id': '2_10',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91658602378945, 40.76625191668435]},
#    'id': '2_11',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91715590645533, 40.76683393415903]},
#    'id': '2_12',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9280798169411, 40.76488190305168]},
#    'id': '2_13',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91939868959375, 40.76301930976759]},
#    'id': '2_14',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91929357605814, 40.767526024838816]},
#    'id': '2_15',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92410845571196, 40.7670701260946]},
#    'id': '2_16',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92330899999226, 40.76808235624977]},
#    'id': '2_17',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92823900913149, 40.765432756821625]},
#    'id': '2_18',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92255672843007, 40.76609871918763]},
#    'id': '2_19',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92615193718883, 40.76465436186263]},
#    'id': '2_20',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9229180500496, 40.76688455602875]},
#    'id': '2_21',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92366280546864, 40.76594347530442]},
#    'id': '2_22',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92027486666326, 40.76651180417262]},
#    'id': '2_23',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9182722380914, 40.7672729786607]},
#    'id': '2_24',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92739052890501, 40.76483923939484]},
#    'id': '2_25',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91990664530465, 40.76332544615624]},
#    'id': '2_26',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92228169693055, 40.76840764705168]},
#    'id': '2_27',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92402695122342, 40.76824389645122]},
#    'id': '2_28',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91456806585691, 40.76575305543385]},
#    'id': '2_29',
#    'properties': {'landcover': 0}}]}

# %%
randomPts_dict.keys()
# Out:
# dict_keys(['Hudson01Pts', 'Hudson02Pts', 'Bronx01Pts', 'Astoria01Pts'])

# %%
fc = ee.FeatureCollection([])
for x in randomPts_dict.keys():
    print(x)
    fc = fc.merge(randomPts_dict[x])
# Out:
# Hudson01Pts
# Hudson02Pts
# Bronx01Pts
# Astoria01Pts

# %%
training.getInfo()
# Out:
# {'type': 'FeatureCollection',
#  'columns': {},
#  'properties': {'band_order': ['B2',
#    'B3',
#    'B4',
#    'B5',
#    'B6',
#    'B7',
#    'B10',
#    'B11']},
#  'features': [{'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_0_0',
#    'properties': {'B10': 25821,
#     'B11': 23754,
#     'B2': 11031,
#     'B3': 10460,
#     'B4': 9760,
#     'B5': 7982,
#     'B6': 7081,
#     'B7': 6632,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_1_0',
#    'properties': {'B10': 25826,
#     'B11': 23761,
#     'B2': 11252,
#     'B3': 10765,
#     'B4': 10116,
#     'B5': 8386,
#     'B6': 7471,
#     'B7': 6932,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_2_0',
#    'properties': {'B10': 25910,
#     'B11': 23806,
#     'B2': 10960,
#     'B3': 10415,
#     'B4': 9754,
#     'B5': 7992,
#     'B6': 6992,
#     'B7': 6597,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_3_0',
#    'properties': {'B10': 25814,
#     'B11': 23783,
#     'B2': 11029,
#     'B3': 10468,
#     'B4': 9778,
#     'B5': 8052,
#     'B6': 7086,
#     'B7': 6697,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_4_0',
#    'properties': {'B10': 25835,
#     'B11': 23775,
#     'B2': 11368,
#     'B3': 10847,
#     'B4': 10273,
#     'B5': 8549,
#     'B6': 7563,
#     'B7': 7075,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_5_0',
#    'properties': {'B10': 25850,
#     'B11': 23827,
#     'B2': 10723,
#     'B3': 10108,
#     'B4': 9465,
#     'B5': 7521,
#     'B6': 6634,
#     'B7': 6299,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_6_0',
#    'properties': {'B10': 25864,
#     'B11': 23812,
#     'B2': 11064,
#     'B3': 10475,
#     'B4': 9784,
#     'B5': 8029,
#     'B6': 7135,
#     'B7': 6704,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_7_0',
#    'properties': {'B10': 25765,
#     'B11': 23716,
#     'B2': 11435,
#     'B3': 10895,
#     'B4': 10376,
#     'B5': 8600,
#     'B6': 7631,
#     'B7': 7082,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_8_0',
#    'properties': {'B10': 25866,
#     'B11': 23805,
#     'B2': 11094,
#     'B3': 10506,
#     'B4': 9785,
#     'B5': 8019,
#     'B6': 7159,
#     'B7': 6732,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_9_0',
#    'properties': {'B10': 25843,
#     'B11': 23801,
#     'B2': 11079,
#     'B3': 10456,
#     'B4': 9784,
#     'B5': 8051,
#     'B6': 7163,
#     'B7': 6717,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_10_0',
#    'properties': {'B10': 25875,
#     'B11': 23855,
#     'B2': 11011,
#     'B3': 10427,
#     'B4': 9765,
#     'B5': 7950,
#     'B6': 7035,
#     'B7': 6595,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_11_0',
#    'properties': {'B10': 25806,
#     'B11': 23754,
#     'B2': 11209,
#     'B3': 10728,
#     'B4': 10111,
#     'B5': 8360,
#     'B6': 7429,
#     'B7': 6932,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_12_0',
#    'properties': {'B10': 25999,
#     'B11': 23893,
#     'B2': 10781,
#     'B3': 10100,
#     'B4': 9680,
#     'B5': 7604,
#     'B6': 6583,
#     'B7': 6245,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_13_0',
#    'properties': {'B10': 25860,
#     'B11': 23829,
#     'B2': 10993,
#     'B3': 10399,
#     'B4': 9969,
#     'B5': 8013,
#     'B6': 6957,
#     'B7': 6547,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_14_0',
#    'properties': {'B10': 25857,
#     'B11': 23802,
#     'B2': 10996,
#     'B3': 10398,
#     'B4': 9693,
#     'B5': 7920,
#     'B6': 7101,
#     'B7': 6650,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_15_0',
#    'properties': {'B10': 25874,
#     'B11': 23779,
#     'B2': 11043,
#     'B3': 10490,
#     'B4': 9859,
#     'B5': 7992,
#     'B6': 7119,
#     'B7': 6659,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_16_0',
#    'properties': {'B10': 25844,
#     'B11': 23771,
#     'B2': 11087,
#     'B3': 10527,
#     'B4': 9809,
#     'B5': 8090,
#     'B6': 7187,
#     'B7': 6739,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_17_0',
#    'properties': {'B10': 25831,
#     'B11': 23795,
#     'B2': 11141,
#     'B3': 10562,
#     'B4': 9921,
#     'B5': 8172,
#     'B6': 7246,
#     'B7': 6818,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_18_0',
#    'properties': {'B10': 25767,
#     'B11': 23724,
#     'B2': 11050,
#     'B3': 10497,
#     'B4': 9796,
#     'B5': 8030,
#     'B6': 7146,
#     'B7': 6666,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_19_0',
#    'properties': {'B10': 25887,
#     'B11': 23844,
#     'B2': 10959,
#     'B3': 10363,
#     'B4': 9808,
#     'B5': 7907,
#     'B6': 6986,
#     'B7': 6532,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_20_0',
#    'properties': {'B10': 25875,
#     'B11': 23855,
#     'B2': 10900,
#     'B3': 10307,
#     'B4': 9678,
#     'B5': 7798,
#     'B6': 6872,
#     'B7': 6484,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_21_0',
#    'properties': {'B10': 25872,
#     'B11': 23778,
#     'B2': 11031,
#     'B3': 10474,
#     'B4': 9870,
#     'B5': 7958,
#     'B6': 7057,
#     'B7': 6642,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_22_0',
#    'properties': {'B10': 25888,
#     'B11': 23833,
#     'B2': 10958,
#     'B3': 10345,
#     'B4': 9816,
#     'B5': 7901,
#     'B6': 6921,
#     'B7': 6509,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_23_0',
#    'properties': {'B10': 25833,
#     'B11': 23808,
#     'B2': 11087,
#     'B3': 10497,
#     'B4': 9811,
#     'B5': 8090,
#     'B6': 7170,
#     'B7': 6754,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_24_0',
#    'properties': {'B10': 25991,
#     'B11': 23928,
#     'B2': 10685,
#     'B3': 9979,
#     'B4': 9521,
#     'B5': 7462,
#     'B6': 6396,
#     'B7': 6111,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_25_0',
#    'properties': {'B10': 25853,
#     'B11': 23821,
#     'B2': 11032,
#     'B3': 10425,
#     'B4': 9994,
#     'B5': 8053,
#     'B6': 7018,
#     'B7': 6623,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_26_0',
#    'properties': {'B10': 25845,
#     'B11': 23791,
#     'B2': 11037,
#     'B3': 10444,
#     'B4': 9735,
#     'B5': 7986,
#     'B6': 7100,
#     'B7': 6666,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_27_0',
#    'properties': {'B10': 25859,
#     'B11': 23812,
#     'B2': 11105,
#     'B3': 10547,
#     'B4': 9859,
#     'B5': 8144,
#     'B6': 7247,
#     'B7': 6815,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_28_0',
#    'properties': {'B10': 25856,
#     'B11': 23779,
#     'B2': 11376,
#     'B3': 10878,
#     'B4': 10209,
#     'B5': 8545,
#     'B6': 7646,
#     'B7': 7088,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_1_2_29_0',
#    'properties': {'B10': 25930,
#     'B11': 23871,
#     'B2': 11087,
#     'B3': 10536,
#     'B4': 9866,
#     'B5': 8103,
#     'B6': 7263,
#     'B7': 6826,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_0_0',
#    'properties': {'B10': 25893,
#     'B11': 23779,
#     'B2': 11053,
#     'B3': 10511,
#     'B4': 9863,
#     'B5': 8173,
#     'B6': 7123,
#     'B7': 6689,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_1_0',
#    'properties': {'B10': 25794,
#     'B11': 23731,
#     'B2': 11113,
#     'B3': 10610,
#     'B4': 9913,
#     'B5': 8182,
#     'B6': 7261,
#     'B7': 6803,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_2_0',
#    'properties': {'B10': 25812,
#     'B11': 23725,
#     'B2': 11226,
#     'B3': 10719,
#     'B4': 10099,
#     'B5': 8375,
#     'B6': 7401,
#     'B7': 6910,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_3_0',
#    'properties': {'B10': 25780,
#     'B11': 23752,
#     'B2': 10951,
#     'B3': 10325,
#     'B4': 10088,
#     'B5': 8233,
#     'B6': 6953,
#     'B7': 6537,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_4_0',
#    'properties': {'B10': 25940,
#     'B11': 23869,
#     'B2': 10872,
#     'B3': 10285,
#     'B4': 9588,
#     'B5': 7863,
#     'B6': 6886,
#     'B7': 6496,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_5_0',
#    'properties': {'B10': 25892,
#     'B11': 23822,
#     'B2': 10951,
#     'B3': 10427,
#     'B4': 9869,
#     'B5': 7999,
#     'B6': 6966,
#     'B7': 6581,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_6_0',
#    'properties': {'B10': 25801,
#     'B11': 23752,
#     'B2': 11171,
#     'B3': 10674,
#     'B4': 10007,
#     'B5': 8287,
#     'B6': 7374,
#     'B7': 6889,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_7_0',
#    'properties': {'B10': 25819,
#     'B11': 23747,
#     'B2': 11008,
#     'B3': 10459,
#     'B4': 9762,
#     'B5': 8024,
#     'B6': 7113,
#     'B7': 6690,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_8_0',
#    'properties': {'B10': 25869,
#     'B11': 23761,
#     'B2': 11202,
#     'B3': 10648,
#     'B4': 10099,
#     'B5': 8385,
#     'B6': 7345,
#     'B7': 6842,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_9_0',
#    'properties': {'B10': 25956,
#     'B11': 23845,
#     'B2': 11152,
#     'B3': 10655,
#     'B4': 10080,
#     'B5': 8331,
#     'B6': 7353,
#     'B7': 6876,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_10_0',
#    'properties': {'B10': 25921,
#     'B11': 23827,
#     'B2': 11057,
#     'B3': 10515,
#     'B4': 10019,
#     'B5': 8193,
#     'B6': 7274,
#     'B7': 6788,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_11_0',
#    'properties': {'B10': 26017,
#     'B11': 23857,
#     'B2': 10940,
#     'B3': 10400,
#     'B4': 9769,
#     'B5': 8125,
#     'B6': 7079,
#     'B7': 6648,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_12_0',
#    'properties': {'B10': 25934,
#     'B11': 23833,
#     'B2': 11176,
#     'B3': 10663,
#     'B4': 10188,
#     'B5': 8389,
#     'B6': 7189,
#     'B7': 6709,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_13_0',
#    'properties': {'B10': 25929,
#     'B11': 23851,
#     'B2': 11191,
#     'B3': 10676,
#     'B4': 10074,
#     'B5': 8343,
#     'B6': 7395,
#     'B7': 6897,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_14_0',
#    'properties': {'B10': 25842,
#     'B11': 23790,
#     'B2': 11353,
#     'B3': 10855,
#     'B4': 10217,
#     'B5': 8598,
#     'B6': 7644,
#     'B7': 7071,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_15_0',
#    'properties': {'B10': 25844,
#     'B11': 23768,
#     'B2': 11170,
#     'B3': 10655,
#     'B4': 10143,
#     'B5': 8333,
#     'B6': 7235,
#     'B7': 6756,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_16_0',
#    'properties': {'B10': 25867,
#     'B11': 23805,
#     'B2': 11139,
#     'B3': 10601,
#     'B4': 9968,
#     'B5': 8221,
#     'B6': 7202,
#     'B7': 6742,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_17_0',
#    'properties': {'B10': 25845,
#     'B11': 23773,
#     'B2': 10977,
#     'B3': 10400,
#     'B4': 9732,
#     'B5': 7981,
#     'B6': 7002,
#     'B7': 6599,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_18_0',
#    'properties': {'B10': 25819,
#     'B11': 23754,
#     'B2': 11117,
#     'B3': 10607,
#     'B4': 9930,
#     'B5': 8172,
#     'B6': 7276,
#     'B7': 6796,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_19_0',
#    'properties': {'B10': 25873,
#     'B11': 23779,
#     'B2': 11081,
#     'B3': 10529,
#     'B4': 10055,
#     'B5': 8288,
#     'B6': 7294,
#     'B7': 6811,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_20_0',
#    'properties': {'B10': 25849,
#     'B11': 23813,
#     'B2': 10956,
#     'B3': 10395,
#     'B4': 10063,
#     'B5': 8093,
#     'B6': 6899,
#     'B7': 6490,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_21_0',
#    'properties': {'B10': 25862,
#     'B11': 23776,
#     'B2': 10935,
#     'B3': 10396,
#     'B4': 9758,
#     'B5': 7963,
#     'B6': 6990,
#     'B7': 6572,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_22_0',
#    'properties': {'B10': 25879,
#     'B11': 23777,
#     'B2': 11102,
#     'B3': 10597,
#     'B4': 10067,
#     'B5': 8273,
#     'B6': 7314,
#     'B7': 6838,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_23_0',
#    'properties': {'B10': 25806,
#     'B11': 23773,
#     'B2': 11026,
#     'B3': 10399,
#     'B4': 10181,
#     'B5': 8476,
#     'B6': 7093,
#     'B7': 6643,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_24_0',
#    'properties': {'B10': 25904,
#     'B11': 23866,
#     'B2': 11149,
#     'B3': 10635,
#     'B4': 10297,
#     'B5': 8315,
#     'B6': 7111,
#     'B7': 6670,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_25_0',
#    'properties': {'B10': 25943,
#     'B11': 23840,
#     'B2': 11160,
#     'B3': 10662,
#     'B4': 10068,
#     'B5': 8318,
#     'B6': 7373,
#     'B7': 6889,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_26_0',
#    'properties': {'B10': 25825,
#     'B11': 23766,
#     'B2': 11385,
#     'B3': 10899,
#     'B4': 10285,
#     'B5': 8621,
#     'B6': 7679,
#     'B7': 7104,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_27_0',
#    'properties': {'B10': 25865,
#     'B11': 23756,
#     'B2': 10987,
#     'B3': 10445,
#     'B4': 9755,
#     'B5': 8009,
#     'B6': 7062,
#     'B7': 6642,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_28_0',
#    'properties': {'B10': 25852,
#     'B11': 23772,
#     'B2': 10792,
#     'B3': 10224,
#     'B4': 9554,
#     'B5': 7727,
#     'B6': 6780,
#     'B7': 6422,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_1_2_29_0',
#    'properties': {'B10': 25848,
#     'B11': 23751,
#     'B2': 10845,
#     'B3': 10267,
#     'B4': 9624,
#     'B5': 7820,
#     'B6': 6862,
#     'B7': 6457,
#     'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_0_0',
#    'properties': {'B10': 30797,
#     'B11': 27171,
#     'B2': 10129,
#     'B3': 9519,
#     'B4': 8589,
#     'B5': 18946,
#     'B6': 13413,
#     'B7': 10282,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_1_0',
#    'properties': {'B10': 32133,
#     'B11': 28059,
#     'B2': 10599,
#     'B3': 9816,
#     'B4': 9422,
#     'B5': 13992,
#     'B6': 11198,
#     'B7': 9337,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_2_0',
#    'properties': {'B10': 32192,
#     'B11': 27985,
#     'B2': 11160,
#     'B3': 10982,
#     'B4': 10496,
#     'B5': 14420,
#     'B6': 13134,
#     'B7': 11827,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_3_0',
#    'properties': {'B10': 31444,
#     'B11': 27455,
#     'B2': 13769,
#     'B3': 12424,
#     'B4': 12373,
#     'B5': 15420,
#     'B6': 14131,
#     'B7': 13046,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_4_0',
#    'properties': {'B10': 31693,
#     'B11': 27640,
#     'B2': 13442,
#     'B3': 12357,
#     'B4': 12653,
#     'B5': 14893,
#     'B6': 14332,
#     'B7': 12912,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_5_0',
#    'properties': {'B10': 31640,
#     'B11': 27662,
#     'B2': 11484,
#     'B3': 10866,
#     'B4': 10613,
#     'B5': 14208,
#     'B6': 12098,
#     'B7': 10943,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_6_0',
#    'properties': {'B10': 32001,
#     'B11': 27871,
#     'B2': 11892,
#     'B3': 11195,
#     'B4': 11139,
#     'B5': 11487,
#     'B6': 10370,
#     'B7': 9916,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_7_0',
#    'properties': {'B10': 31007,
#     'B11': 27385,
#     'B2': 10144,
#     'B3': 9739,
#     'B4': 8678,
#     'B5': 21520,
#     'B6': 13275,
#     'B7': 9624,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_8_0',
#    'properties': {'B10': 32748,
#     'B11': 28323,
#     'B2': 11585,
#     'B3': 11051,
#     'B4': 10828,
#     'B5': 14439,
#     'B6': 12937,
#     'B7': 11607,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_9_0',
#    'properties': {'B10': 29739,
#     'B11': 26539,
#     'B2': 9619,
#     'B3': 8921,
#     'B4': 7679,
#     'B5': 19871,
#     'B6': 12056,
#     'B7': 8376,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_10_0',
#    'properties': {'B10': 32103,
#     'B11': 27986,
#     'B2': 14281,
#     'B3': 14265,
#     'B4': 13930,
#     'B5': 15726,
#     'B6': 18913,
#     'B7': 17663,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_11_0',
#    'properties': {'B10': 31443,
#     'B11': 27640,
#     'B2': 12222,
#     'B3': 13098,
#     'B4': 12354,
#     'B5': 16772,
#     'B6': 17071,
#     'B7': 15234,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_12_0',
#    'properties': {'B10': 30574,
#     'B11': 26948,
#     'B2': 10042,
#     'B3': 9519,
#     'B4': 9255,
#     'B5': 12932,
#     'B6': 11913,
#     'B7': 9334,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_13_0',
#    'properties': {'B10': 32633,
#     'B11': 28323,
#     'B2': 21039,
#     'B3': 22862,
#     'B4': 24956,
#     'B5': 27981,
#     'B6': 24803,
#     'B7': 14739,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_14_0',
#    'properties': {'B10': 31751,
#     'B11': 27846,
#     'B2': 11491,
#     'B3': 10850,
#     'B4': 10743,
#     'B5': 14093,
#     'B6': 12867,
#     'B7': 10783,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_15_0',
#    'properties': {'B10': 31393,
#     'B11': 27322,
#     'B2': 10101,
#     'B3': 9140,
#     'B4': 8247,
#     'B5': 15100,
#     'B6': 10970,
#     'B7': 8630,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_16_0',
#    'properties': {'B10': 33157,
#     'B11': 28923,
#     'B2': 11016,
#     'B3': 10300,
#     'B4': 9996,
#     'B5': 12067,
#     'B6': 11587,
#     'B7': 9972,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_17_0',
#    'properties': {'B10': 32820,
#     'B11': 28551,
#     'B2': 20884,
#     'B3': 20274,
#     'B4': 21760,
#     'B5': 24292,
#     'B6': 27320,
#     'B7': 25139,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_18_0',
#    'properties': {'B10': 33597,
#     'B11': 28965,
#     'B2': 11151,
#     'B3': 9942,
#     'B4': 9399,
#     'B5': 10081,
#     'B6': 11311,
#     'B7': 10463,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_19_0',
#    'properties': {'B10': 32442,
#     'B11': 28178,
#     'B2': 12046,
#     'B3': 11569,
#     'B4': 11711,
#     'B5': 13406,
#     'B6': 12844,
#     'B7': 11826,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_20_0',
#    'properties': {'B10': 33081,
#     'B11': 28900,
#     'B2': 10889,
#     'B3': 9977,
#     'B4': 9865,
#     'B5': 10528,
#     'B6': 9853,
#     'B7': 9427,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_21_0',
#    'properties': {'B10': 31809,
#     'B11': 27899,
#     'B2': 11221,
#     'B3': 10554,
#     'B4': 10080,
#     'B5': 14403,
#     'B6': 12020,
#     'B7': 10081,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_22_0',
#    'properties': {'B10': 31630,
#     'B11': 27794,
#     'B2': 14267,
#     'B3': 13818,
#     'B4': 13537,
#     'B5': 14991,
#     'B6': 18442,
#     'B7': 16934,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_23_0',
#    'properties': {'B10': 32871,
#     'B11': 28352,
#     'B2': 19547,
#     'B3': 22224,
#     'B4': 23270,
#     'B5': 24391,
#     'B6': 34122,
#     'B7': 31193,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_24_0',
#    'properties': {'B10': 31405,
#     'B11': 27530,
#     'B2': 15223,
#     'B3': 15974,
#     'B4': 15744,
#     'B5': 21423,
#     'B6': 49315,
#     'B7': 55767,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_25_0',
#    'properties': {'B10': 32789,
#     'B11': 28387,
#     'B2': 10970,
#     'B3': 10072,
#     'B4': 9905,
#     'B5': 10177,
#     'B6': 10641,
#     'B7': 9975,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_26_0',
#    'properties': {'B10': 31927,
#     'B11': 27834,
#     'B2': 11891,
#     'B3': 11353,
#     'B4': 10980,
#     'B5': 11908,
#     'B6': 11966,
#     'B7': 11075,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_27_0',
#    'properties': {'B10': 31546,
#     'B11': 27580,
#     'B2': 11643,
#     'B3': 10885,
#     'B4': 9893,
#     'B5': 18650,
#     'B6': 16409,
#     'B7': 12789,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_28_0',
#    'properties': {'B10': 32750,
#     'B11': 28396,
#     'B2': 14682,
#     'B3': 13024,
#     'B4': 14304,
#     'B5': 16756,
#     'B6': 15008,
#     'B7': 13969,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1_2_29_0',
#    'properties': {'B10': 31689,
#     'B11': 27856,
#     'B2': 11302,
#     'B3': 10347,
#     'B4': 10207,
#     'B5': 12286,
#     'B6': 11860,
#     'B7': 10137,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_0_0',
#    'properties': {'B10': 30487,
#     'B11': 26908,
#     'B2': 15018,
#     'B3': 14534,
#     'B4': 14473,
#     'B5': 17744,
#     'B6': 18863,
#     'B7': 17067,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_1_0',
#    'properties': {'B10': 30564,
#     'B11': 26905,
#     'B2': 16358,
#     'B3': 17195,
#     'B4': 17748,
#     'B5': 20461,
#     'B6': 21895,
#     'B7': 20205,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_2_0',
#    'properties': {'B10': 31180,
#     'B11': 27378,
#     'B2': 13607,
#     'B3': 12783,
#     'B4': 12670,
#     'B5': 16585,
#     'B6': 17136,
#     'B7': 14819,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_3_0',
#    'properties': {'B10': 31065,
#     'B11': 27235,
#     'B2': 12253,
#     'B3': 11372,
#     'B4': 11255,
#     'B5': 13574,
#     'B6': 13596,
#     'B7': 12213,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_4_0',
#    'properties': {'B10': 31684,
#     'B11': 27729,
#     'B2': 12057,
#     'B3': 12272,
#     'B4': 12219,
#     'B5': 13762,
#     'B6': 14391,
#     'B7': 12797,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_5_0',
#    'properties': {'B10': 30973,
#     'B11': 27181,
#     'B2': 13250,
#     'B3': 12059,
#     'B4': 12248,
#     'B5': 16219,
#     'B6': 14784,
#     'B7': 13149,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_6_0',
#    'properties': {'B10': 31276,
#     'B11': 27389,
#     'B2': 14643,
#     'B3': 14580,
#     'B4': 14996,
#     'B5': 17732,
#     'B6': 19072,
#     'B7': 17536,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_7_0',
#    'properties': {'B10': 31446,
#     'B11': 27484,
#     'B2': 14985,
#     'B3': 15297,
#     'B4': 16507,
#     'B5': 18430,
#     'B6': 18329,
#     'B7': 17455,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_8_0',
#    'properties': {'B10': 30791,
#     'B11': 27129,
#     'B2': 12544,
#     'B3': 12328,
#     'B4': 12456,
#     'B5': 13408,
#     'B6': 12056,
#     'B7': 11358,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_9_0',
#    'properties': {'B10': 31177,
#     'B11': 27470,
#     'B2': 13534,
#     'B3': 13825,
#     'B4': 13823,
#     'B5': 15241,
#     'B6': 17113,
#     'B7': 16019,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_10_0',
#    'properties': {'B10': 30738,
#     'B11': 27129,
#     'B2': 11825,
#     'B3': 11338,
#     'B4': 10685,
#     'B5': 15741,
#     'B6': 13907,
#     'B7': 11736,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_11_0',
#    'properties': {'B10': 30633,
#     'B11': 27060,
#     'B2': 15241,
#     'B3': 13916,
#     'B4': 14564,
#     'B5': 17499,
#     'B6': 16383,
#     'B7': 15587,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_12_0',
#    'properties': {'B10': 30770,
#     'B11': 27013,
#     'B2': 13621,
#     'B3': 13487,
#     'B4': 12839,
#     'B5': 15641,
#     'B6': 17028,
#     'B7': 15682,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_13_0',
#    'properties': {'B10': 31021,
#     'B11': 27322,
#     'B2': 16103,
#     'B3': 16198,
#     'B4': 17097,
#     'B5': 19201,
#     'B6': 20734,
#     'B7': 19038,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_14_0',
#    'properties': {'B10': 30797,
#     'B11': 27093,
#     'B2': 15088,
#     'B3': 15445,
#     'B4': 15726,
#     'B5': 18345,
#     'B6': 21128,
#     'B7': 18595,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_15_0',
#    'properties': {'B10': 30931,
#     'B11': 27168,
#     'B2': 13554,
#     'B3': 13349,
#     'B4': 13472,
#     'B5': 15643,
#     'B6': 16895,
#     'B7': 15157,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_16_0',
#    'properties': {'B10': 31268,
#     'B11': 27453,
#     'B2': 13167,
#     'B3': 11736,
#     'B4': 11868,
#     'B5': 13917,
#     'B6': 14994,
#     'B7': 13083,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_17_0',
#    'properties': {'B10': 31229,
#     'B11': 27314,
#     'B2': 12749,
#     'B3': 11809,
#     'B4': 12237,
#     'B5': 16360,
#     'B6': 14462,
#     'B7': 12400,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_18_0',
#    'properties': {'B10': 30924,
#     'B11': 27207,
#     'B2': 13325,
#     'B3': 12557,
#     'B4': 13038,
#     'B5': 15434,
#     'B6': 15676,
#     'B7': 13942,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_19_0',
#    'properties': {'B10': 31215,
#     'B11': 27486,
#     'B2': 14088,
#     'B3': 13836,
#     'B4': 14067,
#     'B5': 15523,
#     'B6': 16079,
#     'B7': 15429,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_20_0',
#    'properties': {'B10': 30605,
#     'B11': 27090,
#     'B2': 14229,
#     'B3': 13300,
#     'B4': 14069,
#     'B5': 16686,
#     'B6': 16140,
#     'B7': 14929,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_21_0',
#    'properties': {'B10': 31408,
#     'B11': 27548,
#     'B2': 13348,
#     'B3': 13577,
#     'B4': 14218,
#     'B5': 15992,
#     'B6': 17792,
#     'B7': 16124,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_22_0',
#    'properties': {'B10': 30968,
#     'B11': 27016,
#     'B2': 16384,
#     'B3': 18967,
#     'B4': 20792,
#     'B5': 22698,
#     'B6': 22729,
#     'B7': 22063,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_23_0',
#    'properties': {'B10': 31150,
#     'B11': 27471,
#     'B2': 12933,
#     'B3': 13276,
#     'B4': 14072,
#     'B5': 14652,
#     'B6': 17082,
#     'B7': 15674,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_24_0',
#    'properties': {'B10': 30954,
#     'B11': 27177,
#     'B2': 13628,
#     'B3': 13354,
#     'B4': 13314,
#     'B5': 14995,
#     'B6': 15494,
#     'B7': 14462,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_25_0',
#    'properties': {'B10': 30905,
#     'B11': 27236,
#     'B2': 13765,
#     'B3': 13347,
#     'B4': 13824,
#     'B5': 15878,
#     'B6': 15998,
#     'B7': 14748,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_26_0',
#    'properties': {'B10': 30527,
#     'B11': 26923,
#     'B2': 17104,
#     'B3': 16409,
#     'B4': 17497,
#     'B5': 20296,
#     'B6': 19488,
#     'B7': 18419,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_27_0',
#    'properties': {'B10': 30957,
#     'B11': 27158,
#     'B2': 15208,
#     'B3': 16926,
#     'B4': 17830,
#     'B5': 21929,
#     'B6': 25139,
#     'B7': 21445,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_28_0',
#    'properties': {'B10': 31229,
#     'B11': 27422,
#     'B2': 12382,
#     'B3': 12743,
#     'B4': 12679,
#     'B5': 16331,
#     'B6': 15786,
#     'B7': 14140,
#     'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2_29_0',
#    'properties': {'B10': 30928,
#     'B11': 27160,
#     'B2': 13380,
#     'B3': 12572,
#     'B4': 12469,
#     'B5': 14529,
#     'B6': 15936,
#     'B7': 14162,
#     'landcover': 0}}]}

# %%
fc.getInfo()
# Out:
# {'type': 'FeatureCollection',
#  'columns': {},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97726913448903, 40.80338152219788]},
#    'id': '1_1_1_2_0',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96308775134366, 40.82843265930131]},
#    'id': '1_1_1_2_1',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.95761005004844, 40.84776534504073]},
#    'id': '1_1_1_2_2',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98212436310615, 40.79733458724368]},
#    'id': '1_1_1_2_3',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.95515245391664, 40.835706162212276]},
#    'id': '1_1_1_2_4',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98454721702588, 40.796822194775984]},
#    'id': '1_1_1_2_5',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98541469961975, 40.79179870176999]},
#    'id': '1_1_1_2_6',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9617751516699, 40.83534902988346]},
#    'id': '1_1_1_2_7',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9864166821032, 40.79159075870921]},
#    'id': '1_1_1_2_8',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98286424708584, 40.79560622044268]},
#    'id': '1_1_1_2_9',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97524317791985, 40.81207140261596]},
#    'id': '1_1_1_2_10',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9528559673429, 40.84238548075046]},
#    'id': '1_1_1_2_11',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97355454085583, 40.817686633532716]},
#    'id': '1_1_1_2_12',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97034603756892, 40.82052859100451]},
#    'id': '1_1_1_2_13',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96551066224514, 40.82033811461513]},
#    'id': '1_1_1_2_14',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98610292616212, 40.79466395608381]},
#    'id': '1_1_1_2_15',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96796555519884, 40.820242042438025]},
#    'id': '1_1_1_2_16',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9699518786234, 40.81402250288002]},
#    'id': '1_1_1_2_17',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.95821733959389, 40.84385665958896]},
#    'id': '1_1_1_2_18',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98170597599717, 40.80347573801371]},
#    'id': '1_1_1_2_19',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9753984974232, 40.81164887877697]},
#    'id': '1_1_1_2_20',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9884106693513, 40.79096231154915]},
#    'id': '1_1_1_2_21',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9779984996434, 40.80884878541013]},
#    'id': '1_1_1_2_22',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98182296875586, 40.79671628768962]},
#    'id': '1_1_1_2_23',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97447508756919, 40.81650932041327]},
#    'id': '1_1_1_2_24',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.97075696141155, 40.81945222901834]},
#    'id': '1_1_1_2_25',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96556015685822, 40.821234862316935]},
#    'id': '1_1_1_2_26',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98254379037982, 40.79466365669443]},
#    'id': '1_1_1_2_27',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.96164476489672, 40.826396877826106]},
#    'id': '1_1_1_2_28',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.98507029063272, 40.79048848623656]},
#    'id': '1_1_1_2_29',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93552247679578, 40.872233618646526]},
#    'id': '1_1_2_0',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94363938214886, 40.86232822342618]},
#    'id': '1_1_2_1',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94798588359137, 40.85448597612985]},
#    'id': '1_1_2_2',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93621587788225, 40.88706891403025]},
#    'id': '1_1_2_3',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93513369957786, 40.86925833863237]},
#    'id': '1_1_2_4',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93616556543076, 40.88248108674617]},
#    'id': '1_1_2_5',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94737021279262, 40.85762300436165]},
#    'id': '1_1_2_6',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94052014773933, 40.865980248815795]},
#    'id': '1_1_2_7',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93690994051892, 40.87540514366874]},
#    'id': '1_1_2_8',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93636686735287, 40.87903534225505]},
#    'id': '1_1_2_9',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93799260587662, 40.87834760946709]},
#    'id': '1_1_2_10',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93199525356428, 40.873667934061274]},
#    'id': '1_1_2_11',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94793658823266, 40.866527467134624]},
#    'id': '1_1_2_12',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93559991310752, 40.878852693263504]},
#    'id': '1_1_2_13',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94611998572537, 40.86127466031828]},
#    'id': '1_1_2_14',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.943879992182, 40.87012324578912]},
#    'id': '1_1_2_15',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93757327543996, 40.87188413275667]},
#    'id': '1_1_2_16',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93695160397134, 40.868740785500336]},
#    'id': '1_1_2_17',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94789151199042, 40.85650234006507]},
#    'id': '1_1_2_18',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94062064606223, 40.875712445091985]},
#    'id': '1_1_2_19',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9390663455032, 40.880699686754745]},
#    'id': '1_1_2_20',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93966416119329, 40.87235691277902]},
#    'id': '1_1_2_21',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94024007122668, 40.87527942702987]},
#    'id': '1_1_2_22',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93607871150797, 40.88865016675204]},
#    'id': '1_1_2_23',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94903305268106, 40.86481051253456]},
#    'id': '1_1_2_24',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93633856351026, 40.87908396973311]},
#    'id': '1_1_2_25',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.94542604187335, 40.862545504770665]},
#    'id': '1_1_2_26',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9378908492582, 40.867671000420856]},
#    'id': '1_1_2_27',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92672428890369, 40.89153310370346]},
#    'id': '1_1_2_28',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92561540653048, 40.89030577059908]},
#    'id': '1_1_2_29',
#    'properties': {'landcover': 1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89658322122182, 40.81844704596529]},
#    'id': '1_2_0',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.90793933878902, 40.81969568994555]},
#    'id': '1_2_1',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92207536092175, 40.80999035993362]},
#    'id': '1_2_2',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.90998217578269, 40.81085138942566]},
#    'id': '1_2_3',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89012732238736, 40.82310823395308]},
#    'id': '1_2_4',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.88678205477684, 40.81538717019095]},
#    'id': '1_2_5',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.90608000260443, 40.80734081452122]},
#    'id': '1_2_6',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91242234305072, 40.81345206698678]},
#    'id': '1_2_7',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91447385310862, 40.81534276521771]},
#    'id': '1_2_8',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91209369828665, 40.810669836187955]},
#    'id': '1_2_9',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.88252174132609, 40.81499685253721]},
#    'id': '1_2_10',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.893048064655, 40.82547661569048]},
#    'id': '1_2_11',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9179813491263, 40.80492801241158]},
#    'id': '1_2_12',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89626766794807, 40.80966507036804]},
#    'id': '1_2_13',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.90056945111967, 40.823562308423476]},
#    'id': '1_2_14',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89076840780444, 40.816136082433985]},
#    'id': '1_2_15',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9101673327282, 40.8213062659063]},
#    'id': '1_2_16',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91025711020956, 40.82754202611094]},
#    'id': '1_2_17',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.88018619474161, 40.81332118650753]},
#    'id': '1_2_18',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.8870691840875, 40.81199874406277]},
#    'id': '1_2_19',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89156015972769, 40.811408189192775]},
#    'id': '1_2_20',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9036796213514, 40.81886750993873]},
#    'id': '1_2_21',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.88954128359332, 40.81363751546122]},
#    'id': '1_2_22',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.89205095902274, 40.81068600837269]},
#    'id': '1_2_23',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9207434665599, 40.806429815518534]},
#    'id': '1_2_24',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.88109696957096, 40.81462774296114]},
#    'id': '1_2_25',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.90062552415719, 40.82190111918505]},
#    'id': '1_2_26',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91898338878856, 40.80914916779409]},
#    'id': '1_2_27',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91087490792764, 40.82859942438753]},
#    'id': '1_2_28',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9189827488195, 40.804123612835454]},
#    'id': '1_2_29',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92203629357051, 40.763676621925164]},
#    'id': '2_0',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91871237083838, 40.76422849735108]},
#    'id': '2_1',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92881354132867, 40.76479098474038]},
#    'id': '2_2',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92132891671262, 40.765923751402326]},
#    'id': '2_3',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.93023172339797, 40.76672229998491]},
#    'id': '2_4',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92427437208441, 40.76400309696836]},
#    'id': '2_5',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91749214913304, 40.76251164401785]},
#    'id': '2_6',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91757137161306, 40.762259444594115]},
#    'id': '2_7',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92589614540735, 40.76595893833707]},
#    'id': '2_8',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9206436520613, 40.7661418915763]},
#    'id': '2_9',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9263560939088, 40.764577921904696]},
#    'id': '2_10',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91658602378945, 40.76625191668435]},
#    'id': '2_11',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91715590645533, 40.76683393415903]},
#    'id': '2_12',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9280798169411, 40.76488190305168]},
#    'id': '2_13',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91939868959375, 40.76301930976759]},
#    'id': '2_14',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91929357605814, 40.767526024838816]},
#    'id': '2_15',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92410845571196, 40.7670701260946]},
#    'id': '2_16',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92330899999226, 40.76808235624977]},
#    'id': '2_17',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92823900913149, 40.765432756821625]},
#    'id': '2_18',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92255672843007, 40.76609871918763]},
#    'id': '2_19',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92615193718883, 40.76465436186263]},
#    'id': '2_20',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9229180500496, 40.76688455602875]},
#    'id': '2_21',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92366280546864, 40.76594347530442]},
#    'id': '2_22',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92027486666326, 40.76651180417262]},
#    'id': '2_23',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.9182722380914, 40.7672729786607]},
#    'id': '2_24',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92739052890501, 40.76483923939484]},
#    'id': '2_25',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91990664530465, 40.76332544615624]},
#    'id': '2_26',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92228169693055, 40.76840764705168]},
#    'id': '2_27',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.92402695122342, 40.76824389645122]},
#    'id': '2_28',
#    'properties': {'landcover': 0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.91456806585691, 40.76575305543385]},
#    'id': '2_29',
#    'properties': {'landcover': 0}}]}
